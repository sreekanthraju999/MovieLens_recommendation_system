# %%
import pandas as pd
from collections import Counter
import sys
sys.setrecursionlimit(6500)


data=pd.read_csv("ratings.csv")
movies=pd.read_csv("movies.csv")
data.head(5)
# Out:
#    userId  movieId  rating  timestamp        Date         time
# 0       1        1     4.0  964982703  31/07/2000  12:15:03 AM
# 1       1        3     4.0  964981247  30/07/2000  11:50:47 PM
# 2       1        6     4.0  964982224  31/07/2000  12:07:04 AM
# 3       1       47     5.0  964983815  31/07/2000  12:33:35 AM
# 4       1       50     5.0  964982931  31/07/2000  12:18:51 AM

# %%
print("Enter User Id")
u=int(input())
u1=u
users=data['userId'].values
new_user= 0
new_user_Rlist=[1,2,3]

# New User---
if u not in users:
    new_user=1
    view=data[data['Date'].str.contains('09/2018')]
    
    if(view[view['userId']==1].shape):
        view=view[view['userId']==1
        print("yes")
    print("1.    Action\n2.    Adventure\n3.    Animation\n4.    Children's\n5.    Comedy\n6.    Crime\n7.    Documentary\n8.    Drama\n9.    Fantasy\n")
    print("Please Enter Your three Preferences\n")
    new_user_Rlist[0]=int(input())
    new_user_Rlist[2]=int(input())
    new_user_Rlist[1]=int(input())
    print("Number of Movies taken in consideration for New User = ",view.shape[0])

# Existing User---
else:
    print("Enter '1' for consdering TimeStamp else '0'")
    timestamp_consideration=int(input()) 
    global c
    if(timestamp_consideration==1):
        view=data[data['Date'].str.contains('2018|2017|2016')]
        print("Number of Movies taken in consideration for Existing User Considering Recent TimeStamp= ",view.shape[0])
        c=2
    if(timestamp_consideration==0):
        view=data
        print("Number of Movies taken in consideration for Existing User = ",view.shape[0])        
        c=3
    users=list(dict.fromkeys(users))
    users.remove(u)
# Out:
# Enter User Id
# 611
#        userId  movieId  rating   timestamp        Date        time
# 7144       50     1201     4.0  1536870006  14/09/2018  1:50:06 AM
# 8816       62     1265     4.0  1536618534  11/09/2018  3:58:54 AM
# 8938       62    46976     4.0  1536874645  14/09/2018  3:07:25 AM
# 8948       62    49530     4.5  1536874696  14/09/2018  3:08:16 AM
# 27126     184     2579     4.0  1537094293  16/09/2018  4:08:13 PM
# yes
# 1.    Action
# 2.    Adventure
# 3.    Animation
# 4.    Children's
# 5.    Comedy
# 6.    Crime
# 7.    Documentary
# 8.    Drama
# 9.    Fantasy
#
# Please Enter Your three Preferences
#
# 1
# 2
# 3
# Number of Movies taken in consideration for New User =  604

# %%
list_type=[]
def getCommonList(u):
    global y
    y=u
    view1=view[(view.userId==u)]
    #print("Number of movies Watched by User=",u,"are ",view1.shape[0])
    
    if(view1.shape[0]==0):
        if u in users:
            users.remove(u)
        getCommonList(u+1)

        
    vs=view1.sort_values(["timestamp","userId"], axis=0, 
                 ascending=False, inplace=False)
    l=view1['movieId'].values
    sp=[]
    
    for i in l[0:20]:
        s=movies.loc[movies['movieId'] == i]['genres'].iloc[0]
        sp.extend(s.split(','))
        #print(sp)
        
    sp = map(int, sp)
    r = [x for x, _ in Counter(sp).most_common(2)]
    list_type.extend(r)

if(new_user==0):    
    getCommonList(u)
    list1=list_type
    print("Type of movies watched by user->",u,list1)
    commonList=[]
    for x in users:
        list_type=[]
        getCommonList(x)
        if list_type:
            commonList.extend(list_type)
            #print("Type of movies watched by user->",y,list_type)
# Out:
# Type of movies watched by user-> 196 [8, 1]

# %%
if(new_user==0):
    cl=[]

    vc = pd.Series(commonList).value_counts()
    cl=vc[vc > 10].index.tolist()

    print("Most Common movie geners viewed by all Users ->",cl)
    list2=[]

    list2.extend([item for item in cl if item not in list1])
    print(" \n List of Generes which were not viewed by User ",u)
    print("Collaborative List->",list2)
    list1.extend([item for item in cl if item not in list1])

    print("\n""Recommending List of Geners to user->",u,list1)
# Out:
# Most Common movie geners viewed by all Users -> [8, 1, 5, 16, 2, 6]
#
#  List of Generes which were not viewed by User  196
# Collaborative List-> [5, 16, 2, 6]
#
# Recommending List of Geners to user-> 196 [8, 1, 5, 16, 2, 6]

# %%
if u not in users:
    print("Recommended list1 of movies for user ->",u,"\n")
    c=0
    s=0
    d=movies['genres'].values
    link=movies['links'].values
    name=movies['title'].values

    for i,k in enumerate(d):
        li=k.split(',')
        for j in list1:
            if str(j) in li:
                s=1
                break
            else:
                s=0
        if s==1:
            c=c+1
           # print(li,name[i],link[i])


    print("Total Movies=",c)
# Out:
# Recommended list1 of movies for user -> 196
#
# Total Movies= 8803

# %%
print("\n\n\n\n\n\n")
if(new_user==1):
    list2=new_user_Rlist
    data=view
print("Listing the Type of Movies recommending for the user by collaborative filtering->",list2)

print("Recommended list2 of movies for user  ->",u,"\n")
from prettytable import PrettyTable
table = PrettyTable(['Movie Name', 'Movie Link','Rating'])



c=0
s=0
c1=0
c2=0
d=movies['genres'].values
link=movies['links'].values
name=movies['title'].values
ids=movies['movieId'].values
for i,k in enumerate(d):
    li=k.split(',')
    for j in list2:
        if str(j) in li:
            s=1
            break
        else:
            s=0
    if s==1:
        t=[]
        view2=view[(view.movieId==ids[i]) & (view.userId!=u1)]
        if view2.shape[0]>0:
            rating=view2['rating'].values;
            import statistics as s
            r1=s.mean(rating)
            
            if r1>=5:
                c=c+1
                table.add_row([name[i],link[i],r1])
            elif r1<3:
                c1=c1+1;
            else :
                c2=c2+1;

print(table)
print("Total Movies with ratings == 5",c)
print("Total Movies with ratings < 3",c1)
print("Total Movies with ratings = 3",c2)
# Out:
# Listing the Type of Movies recommending for the user by collaborative filtering-> [5, 16, 2, 6]
# Recommended list2 of movies for user  -> 196
#
# +-------------------------------------------------------------------------------+--------------------------------------+--------+
# |                                   Movie Name                                  |              Movie Link              | Rating |
# +-------------------------------------------------------------------------------+--------------------------------------+--------+
# |                                  Smoke (1995)                                 | http://www.imdb.com/title/tt0114478  |  5.0   |
# |                         Dead Alive (Braindead) (1992)                         | http://www.imdb.com/title/tt0103873  |  5.0   |
# |                             Night on Earth (1991)                             | http://www.imdb.com/title/tt0102536  |  5.0   |
# |                     Invasion of the Body Snatchers (1956)                     |  http://www.imdb.com/title/tt049366  |  5.0   |
# |                                 Yojimbo (1961)                                |  http://www.imdb.com/title/tt055630  |  5.0   |
# |                        World Is Not Enough, The (1999)                        | http://www.imdb.com/title/tt0143145  |  5.0   |
# |                            Double Indemnity (1944)                            |  http://www.imdb.com/title/tt036775  |  5.0   |
# |                               Dersu Uzala (1975)                              |  http://www.imdb.com/title/tt071411  |  5.0   |
# |                         Outlaw Josey Wales, The (1976)                        |  http://www.imdb.com/title/tt075029  |  5.0   |
# |                          Spy Who Loved Me, The (1977)                         |  http://www.imdb.com/title/tt076752  |  5.0   |
# |                         Stranger Than Paradise (1984)                         |  http://www.imdb.com/title/tt088184  |  5.0   |
# |                                 Barfly (1987)                                 |  http://www.imdb.com/title/tt092618  |  5.0   |
# |                         Phantom of the Paradise (1974)                        |  http://www.imdb.com/title/tt071994  |  5.0   |
# |                                  Opera (1987)                                 |  http://www.imdb.com/title/tt093677  |  5.0   |
# |                      Going Places (Valseuses, Les) (1974)                     |  http://www.imdb.com/title/tt072353  |  5.0   |
# |                             Stuart Little 2 (2002)                            | http://www.imdb.com/title/tt0243585  |  5.0   |
# |                          Visitor Q (Bizita Q) (2001)                          | http://www.imdb.com/title/tt0290329  |  5.0   |
# |                               Siam Sunset (1999)                              | http://www.imdb.com/title/tt0178022  |  5.0   |
# |                                 Duplex (2003)                                 | http://www.imdb.com/title/tt0266489  |  5.0   |
# |      Cabinet of Dr. Caligari, The (Cabinet des Dr. Caligari., Das) (1920)     |  http://www.imdb.com/title/tt010323  |  5.0   |
# |                              Wild at Heart (1990)                             | http://www.imdb.com/title/tt0100935  |  5.0   |
# |                        Dead or Alive: Hanzaisha (1999)                        | http://www.imdb.com/title/tt0221111  |  5.0   |
# |                             Little Murders (1971)                             |  http://www.imdb.com/title/tt067350  |  5.0   |
# |                              Arizona Dream (1993)                             | http://www.imdb.com/title/tt0106307  |  5.0   |
# |                             First Daughter (2004)                             | http://www.imdb.com/title/tt0361620  |  5.0   |
# |                           Tales of Manhattan (1942)                           |  http://www.imdb.com/title/tt035415  |  5.0   |
# |                       Charlie Brown Christmas, A (1965)                       |  http://www.imdb.com/title/tt059026  |  5.0   |
# |                   Branded to Kill (Koroshi no rakuin) (1967)                  |  http://www.imdb.com/title/tt061882  |  5.0   |
# |              Asterix and Cleopatra (Astérix et Cléopâtre) (1968)              |  http://www.imdb.com/title/tt062687  |  5.0   |
# |                          They Call Me Trinity (1971)                          |  http://www.imdb.com/title/tt067355  |  5.0   |
# |                                Cry-Baby (1990)                                |  http://www.imdb.com/title/tt099329  |  5.0   |
# |            Sympathy for Mr. Vengeance (Boksuneun naui geot) (2002)            | http://www.imdb.com/title/tt0310775  |  5.0   |
# |                  Gozu (Gokudô kyôfu dai-gekijô: Gozu) (2003)                  | http://www.imdb.com/title/tt0361668  |  5.0   |
# |                               Saving Face (2004)                              | http://www.imdb.com/title/tt0384504  |  5.0   |
# |                            Land of the Dead (2005)                            | http://www.imdb.com/title/tt0418819  |  5.0   |
# |                            Calcium Kid, The (2004)                            | http://www.imdb.com/title/tt0330111  |  5.0   |
# |                            Weather Man, The (2005)                            | http://www.imdb.com/title/tt0384680  |  5.0   |
# |                            Dead Man's Shoes (2004)                            | http://www.imdb.com/title/tt0419677  |  5.0   |
# |            Match Factory Girl, The (Tulitikkutehtaan tyttö) (1990)            |  http://www.imdb.com/title/tt098532  |  5.0   |
# |                   Go for Zucker! (Alles auf Zucker!) (2004)                   | http://www.imdb.com/title/tt0416331  |  5.0   |
# |                                Mind Game (2004)                               | http://www.imdb.com/title/tt0452039  |  5.0   |
# |                           Chump at Oxford, A (1940)                           |  http://www.imdb.com/title/tt032339  |  5.0   |
# |                           Jackass Number Two (2006)                           | http://www.imdb.com/title/tt0493430  |  5.0   |
# |                             Hannibal Rising (2007)                            | http://www.imdb.com/title/tt0367959  |  5.0   |
# |                       Ugly Duckling and Me!, The (2006)                       | http://www.imdb.com/title/tt0396042  |  5.0   |
# |                               Breed, The (2006)                               | http://www.imdb.com/title/tt0455362  |  5.0   |
# |                         Sun Alley (Sonnenallee) (1999)                        | http://www.imdb.com/title/tt0177242  |  5.0   |
# |                        Valet, The (La doublure) (2006)                        | http://www.imdb.com/title/tt0449851  |  5.0   |
# |                             Lions For Lambs (2007)                            | http://www.imdb.com/title/tt0891527  |  5.0   |
# |                         Watching the Detectives (2007)                        | http://www.imdb.com/title/tt0472205  |  5.0   |
# |                           Gomorrah (Gomorra) (2008)                           | http://www.imdb.com/title/tt0929425  |  5.0   |
# |                           Observe and Report (2009)                           | http://www.imdb.com/title/tt01197628 |  5.0   |
# |                       Confessions of a Shopaholic (2009)                      | http://www.imdb.com/title/tt01093908 |  5.0   |
# |                              Boy Eats Girl (2005)                             | http://www.imdb.com/title/tt0415679  |  5.0   |
# |                     Love Exposure (Ai No Mukidashi) (2008)                    | http://www.imdb.com/title/tt01128075 |  5.0   |
# |                     Mickey's Once Upon a Christmas (1999)                     | http://www.imdb.com/title/tt0238414  |  5.0   |
# |                                Meantime (1984)                                |  http://www.imdb.com/title/tt082727  |  5.0   |
# |                             Mother (Madeo) (2009)                             | http://www.imdb.com/title/tt01216496 |  5.0   |
# |                                 Get Low (2009)                                | http://www.imdb.com/title/tt01194263 |  5.0   |
# |                            Sisters (Syostry) (2001)                           | http://www.imdb.com/title/tt0284492  |  5.0   |
# |                             All Good Things (2010)                            | http://www.imdb.com/title/tt01175709 |  5.0   |
# |                                 Faster (2010)                                 | http://www.imdb.com/title/tt01433108 |  5.0   |
# |                           Down Argentine Way (1940)                           |  http://www.imdb.com/title/tt032410  |  5.0   |
# |                            Girls About Town (1931)                            |  http://www.imdb.com/title/tt021910  |  5.0   |
# |                  Scooby-Doo! Curse of the Lake Monster (2010)                 | http://www.imdb.com/title/tt01618435 |  5.0   |
# |                          Louis C.K.: Shameless (2007)                         | http://www.imdb.com/title/tt0927619  |  5.0   |
# |                   My Life as McDull (Mak dau goo si) (2001)                   | http://www.imdb.com/title/tt0312941  |  5.0   |
# |            Asterix and the Vikings (Astérix et les Vikings) (2006)            | http://www.imdb.com/title/tt0371552  |  5.0   |
# |                             Happy Feet Two (2011)                             | http://www.imdb.com/title/tt01402488 |  5.0   |
# |                             Monsieur Lazhar (2011)                            | http://www.imdb.com/title/tt02011971 |  5.0   |
# |                               Miss Nobody (2010)                              | http://www.imdb.com/title/tt01129427 |  5.0   |
# |                                 Lockout (2012)                                | http://www.imdb.com/title/tt01592525 |  5.0   |
# |                             Goodbye Charlie (1964)                            |  http://www.imdb.com/title/tt058154  |  5.0   |
# |                     Odd Life of Timothy Green, The (2012)                     | http://www.imdb.com/title/tt01462769 |  5.0   |
# |                             Runaway Brain (1995)                              | http://www.imdb.com/title/tt0114308  |  5.0   |
# |           My Left Eye Sees Ghosts (Ngo joh aan gin diy gwai) (2002)           | http://www.imdb.com/title/tt0319901  |  5.0   |
# |                               Jackass 3.5 (2011)                              | http://www.imdb.com/title/tt01753968 |  5.0   |
# |                     Fantastic Fear of Everything, A (2012)                    | http://www.imdb.com/title/tt02006040 |  5.0   |
# |                            English Vinglish (2012)                            | http://www.imdb.com/title/tt02181931 |  5.0   |
# |                        It's Such a Beautiful Day (2012)                       | http://www.imdb.com/title/tt02396224 |  5.0   |
# |                              Maniac Cop 2 (1990)                              | http://www.imdb.com/title/tt0100107  |  5.0   |
# |                    Craig Ferguson: I'm Here To Help (2013)                    | http://www.imdb.com/title/tt02523852 |  5.0   |
# |                 Great Beauty, The (Grande Bellezza, La) (2013)                | http://www.imdb.com/title/tt02358891 |  5.0   |
# |           13 of the Third Planet, The (Tayna tretey planety) (1981)           | http://www.imdb.com/title/tt0211653  |  5.0   |
# |                                Nebraska (2013)                                | http://www.imdb.com/title/tt01821549 |  5.0   |
# |                            Hunting Elephants (2013)                           | http://www.imdb.com/title/tt02295196 |  5.0   |
# |                   Chinese Puzzle (Casse-tête chinois) (2013)                  | http://www.imdb.com/title/tt01937118 |  5.0   |
# |                              Wonder Woman (2009)                              | http://www.imdb.com/title/tt01186373 |  5.0   |
# |       On the Other Side of the Tracks (De l'autre côté du périph) (2012)      | http://www.imdb.com/title/tt01937133 |  5.0   |
# |       Crippled Avengers (Can que) (Return of the 5 Deadly Venoms) (1981)      |  http://www.imdb.com/title/tt077292  |  5.0   |
# |                               Hellbenders (2012)                              | http://www.imdb.com/title/tt01865393 |  5.0   |
# |                       National Lampoon's Bag Boy (2007)                       | http://www.imdb.com/title/tt0906325  |  5.0   |
# |                                   PK (2014)                                   | http://www.imdb.com/title/tt02338151 |  5.0   |
# |                    Stuart Little 3: Call of the Wild (2005)                   | http://www.imdb.com/title/tt0472602  |  5.0   |
# |                                  Guy X (2005)                                 | http://www.imdb.com/title/tt0408828  |  5.0   |
# |                      Snowflake, the White Gorilla (2011)                      | http://www.imdb.com/title/tt01429433 |  5.0   |
# |                      A Flintstones Christmas Carol (1994)                     | http://www.imdb.com/title/tt0193164  |  5.0   |
# |                         The Fox and the Hound 2 (2006)                        | http://www.imdb.com/title/tt0465997  |  5.0   |
# |                     Trinity and Sartana Are Coming (1972)                     |  http://www.imdb.com/title/tt069409  |  5.0   |
# |                      Tom Segura: Completely Normal (2014)                     | http://www.imdb.com/title/tt03500822 |  5.0   |
# |                     George Carlin: It's Bad for Ya! (2008)                    | http://www.imdb.com/title/tt0963207  |  5.0   |
# |                   George Carlin: Life Is Worth Losing (2005)                  | http://www.imdb.com/title/tt0484855  |  5.0   |
# |                              Saving Santa (2013)                              | http://www.imdb.com/title/tt02204315 |  5.0   |
# |                    Tom and Jerry: A Nutcracker Tale (2007)                    | http://www.imdb.com/title/tt01114698 |  5.0   |
# |                               Willy/Milly (1986)                              |  http://www.imdb.com/title/tt092216  |  5.0   |
# |                                 Buzzard (2015)                                | http://www.imdb.com/title/tt02656588 |  5.0   |
# |                              What Love Is (2007)                              | http://www.imdb.com/title/tt0439876  |  5.0   |
# |                            Ghost Graduation (2012)                            | http://www.imdb.com/title/tt01924273 |  5.0   |
# |                    Scooby-Doo! and the Samurai Sword (2009)                   | http://www.imdb.com/title/tt01421378 |  5.0   |
# |                  Scooby-Doo! and the Loch Ness Monster (2004)                 | http://www.imdb.com/title/tt0418141  |  5.0   |
# |                           Big Top Scooby-Doo! (2012)                          | http://www.imdb.com/title/tt02235542 |  5.0   |
# |                        Scooby-Doo Goes Hollywood (1979)                       | http://www.imdb.com/title/tt0191423  |  5.0   |
# |                       George Carlin: Back in Town (1996)                      | http://www.imdb.com/title/tt0246641  |  5.0   |
# |                   George Carlin: You Are All Diseased (1999)                  | http://www.imdb.com/title/tt0246645  |  5.0   |
# |                    Larry David: Curb Your Enthusiasm (1999)                   | http://www.imdb.com/title/tt0218388  |  5.0   |
# |                    Tom and Jerry: Shiver Me Whiskers (2006)                   | http://www.imdb.com/title/tt0808508  |  5.0   |
# |                                 Villain (1971)                                |  http://www.imdb.com/title/tt067952  |  5.0   |
# |                               Tokyo Tribe (2014)                              | http://www.imdb.com/title/tt02808986 |  5.0   |
# |                        Return to Treasure Island (1988)                       | http://www.imdb.com/title/tt0122227  |  5.0   |
# |                       Hollywood Chainsaw Hookers (1988)                       |  http://www.imdb.com/title/tt095312  |  5.0   |
# |                   George Carlin: Jammin' in New York (1992)                   | http://www.imdb.com/title/tt0246643  |  5.0   |
# |                                Deathgasm (2015)                               | http://www.imdb.com/title/tt03705412 |  5.0   |
# |                                12 Chairs (1976)                               |  http://www.imdb.com/title/tt075468  |  5.0   |
# |                          Bloodsucking Bastards (2015)                         | http://www.imdb.com/title/tt03487994 |  5.0   |
# |                                  Oscar (1967)                                 |  http://www.imdb.com/title/tt062083  |  5.0   |
# |                               The Editor (2015)                               | http://www.imdb.com/title/tt03067274 |  5.0   |
# |                                Jump In! (2007)                                | http://www.imdb.com/title/tt0805559  |  5.0   |
# |                              L.A. Slasher (2015)                              | http://www.imdb.com/title/tt02735292 |  5.0   |
# |                             Formula of Love (1984)                            | http://www.imdb.com/title/tt0216755  |  5.0   |
# |                     Dragons: Gift of the Night Fury (2011)                    | http://www.imdb.com/title/tt02065968 |  5.0   |
# |                         Cosmic Scrat-tastrophe (2015)                         | http://www.imdb.com/title/tt05184298 |  5.0   |
# |                                The Girls (1961)                               | http://www.imdb.com/title/tt0134614  |  5.0   |
# |   The 2s of Sherlock Holmes and Doctor Watson: The Treasures of Agra (1983)   |  http://www.imdb.com/title/tt086333  |  5.0   |
# | 2s Of Sherlock Holmes And Dr. Watson: The Twentieth Century Approaches (1986) |  http://www.imdb.com/title/tt091942  |  5.0   |
# |    The 2s of Sherlock Holmes and Doctor Watson: King of Blackmailers (1980)   | http://www.imdb.com/title/tt0459944  |  5.0   |
# |       The 2s of Sherlock Holmes and Dr. Watson: Bloody Signature (1979)       |  http://www.imdb.com/title/tt080263  |  5.0   |
# |              Sherlock Holmes and Dr. Watson: Acquaintance (1979)              |  http://www.imdb.com/title/tt079902  |  5.0   |
# |                              A Perfect Day (2015)                             | http://www.imdb.com/title/tt03577624 |  5.0   |
# |                             Lumberjack Man (2015)                             | http://www.imdb.com/title/tt03201722 |  5.0   |
# |                               Spellbound (2011)                               | http://www.imdb.com/title/tt02132405 |  5.0   |
# |                              Unicorn City (2012)                              | http://www.imdb.com/title/tt01734589 |  5.0   |
# |                              The Love Bug (1997)                              | http://www.imdb.com/title/tt0119571  |  5.0   |
# |                     Ice Age: The Great Egg-Scapade (2016)                     | http://www.imdb.com/title/tt05480340 |  5.0   |
# |                          Tenchi Muyô! In Love (1996)                          | http://www.imdb.com/title/tt0117876  |  5.0   |
# |                             World of Glory (1991)                             | http://www.imdb.com/title/tt0102083  |  5.0   |
# |                                All Yours (2016)                               | http://www.imdb.com/title/tt05368354 |  5.0   |
# |                       Tom Segura: Mostly Stories (2016)                       | http://www.imdb.com/title/tt04970632 |  5.0   |
# |                          Wings, Legs and Tails (1986)                         | http://www.imdb.com/title/tt01350929 |  5.0   |
# |                       The Girl with All the Gifts (2016)                      | http://www.imdb.com/title/tt04547056 |  5.0   |
# |                 Alesha Popovich and Tugarin the Dragon (2004)                 | http://www.imdb.com/title/tt0415481  |  5.0   |
# |                           Junior and Karlson (1968)                           | http://www.imdb.com/title/tt0756316  |  5.0   |
# |                          There Once Was a Dog (1982)                          | http://www.imdb.com/title/tt0216434  |  5.0   |
# |                      Last Year's Snow Was Falling (1983)                      | http://www.imdb.com/title/tt0219233  |  5.0   |
# |                             Karlson Returns (1970)                            | http://www.imdb.com/title/tt0209074  |  5.0   |
# |                    Priklyucheniya Kapitana Vrungelya (1979)                   | http://www.imdb.com/title/tt0219263  |  5.0   |
# |                  Vovka in the Kingdom of Far Far Away (1965)                  | http://www.imdb.com/title/tt0213309  |  5.0   |
# |                          Wow! A Talking Fish! (1983)                          | http://www.imdb.com/title/tt01352408 |  5.0   |
# |                                Fugitives (1986)                               |  http://www.imdb.com/title/tt091093  |  5.0   |
# |                                 Empties (2007)                                | http://www.imdb.com/title/tt0809951  |  5.0   |
# |                                Obsession (1965)                               | http://www.imdb.com/title/tt0862766  |  5.0   |
# |                On the Trail of the Bremen Town Musicians (1973)               | http://www.imdb.com/title/tt0251333  |  5.0   |
# |                          Bobik Visiting Barbos (1977)                         | http://www.imdb.com/title/tt01070753 |  5.0   |
# |                             Loving Vincent (2017)                             | http://www.imdb.com/title/tt03262342 |  5.0   |
# +-------------------------------------------------------------------------------+--------------------------------------+--------+
# Total Movies with ratings == 5 163
# Total Movies with ratings < 3 1461
# Total Movies with ratings = 3 2577
